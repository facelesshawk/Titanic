# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cross_validation import train_test_split
#from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.naive_bayes import GaussianNB 
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\vipul\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train=pd.read_csv("C:\\Users\\vipul\\Desktop\\titanic\\train (1).csv",header=0)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
def maleorfe(var):
    if var=='female':
        return 0
    else:
        return 1

# %%
train['Sex']=train['Sex'].apply(lambda x:maleorfe(x))

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  714.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.699118
# std     257.353842    0.486592    0.836071    0.477990   14.526497
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   20.125000
# 50%     446.000000    0.000000    3.000000    1.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   38.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %% [raw]
# train.shape()

# %%
train.shape
# Out:
# (891, 12)

# %%
test=pd.read_csv("C:\\Users\\vipul\\Desktop\\titanic\\test (1).csv",header=0)

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df=train[['PassengerId', 'Pclass', 'Age', 'SibSp','Parch','Sex','Survived']]

# %%
df.dropna(axis=0,how='any',inplace=True)
# Out:
# C:\Users\vipul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X=df[['PassengerId', 'Pclass', 'Age','Sex']]
y=df['Survived']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.4)

# %%
clf=LogisticRegression()
clf.fit(xtrain,ytrain)
pred=clf.predict(xtest)
acc=accuracy_score(pred,ytest)

# %%
df.shape
# Out:
# (714, 7)

# %%
X.shape
# Out:
# (714, 4)

# %%
ytest.shape
# Out:
# (286,)

# %%
acc
# Out:
# 0.81468531468531469

# %%
test=pd.read_csv("C:\\Users\\vipul\\Desktop\\titanic\\test (1).csv",header=0)

# %%
test['Sex']=test['Sex'].apply(lambda x:maleorfe(x))

# %%
test['Survived'] = np.nan

# %%
test.dropna(axis=1,how='all',inplace=True)

# %%
alldata = pd.concat([train, test]).reset_index(drop=True)

# %%
alldata
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# ...

# %%
df1=alldata[['PassengerId', 'Pclass', 'Age', 'SibSp','Parch','Sex','Survived']]
#

# %%
x_test  = df1[pd.isnull(alldata.Survived)]
#x_test.reset_index(drop=True, inplace=True)
df1.dropna(how='any',inplace=True)
# Out:
# C:\Users\vipul\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X1=df1[['PassengerId', 'Pclass', 'Age','Sex']]
y1=df1['Survived']
xtrain1,xtest1,ytrain1,ytest1=train_test_split(X1,y1,test_size=0.4)

# %%
clf=LogisticRegression()
clf.fit(xtrain1,ytrain1)
pred1=clf.predict(xtest1)
acc1=accuracy_score(pred1,ytest1)

# %%
acc1
# Out:
# 0.82867132867132864

# %%
x_test=test[['PassengerId', 'Pclass', 'Age', 'Sex']]

# %%
x_test
# Out:
#      PassengerId  Pclass   Age  Sex
# 0            892       3  34.5    1
# 1            893       3  47.0    0
# 2            894       2  62.0    1
# 3            895       3  27.0    1
# 4            896       3  22.0    0
# 5            897       3  14.0    1
# 6            898       3  30.0    0
# 7            899       2  26.0    1
# 8            900       3  18.0    0
# 9            901       3  21.0    1
# 10           902       3   NaN    1
# 11           903       1  46.0    1
# 12           904       1  23.0    0
# 13           905       2  63.0    1
# 14           906       1  47.0    0
# 15           907       2  24.0    0
# 16           908       2  35.0    1
# 17           909       3  21.0    1
# 18           910       3  27.0    0
# 19           911       3  45.0    0
# 20           912       1  55.0    1
# 21           913       3   9.0    1
# 22           914       1   NaN    0
# 23           915       1  21.0    1
# 24           916       1  48.0    0
# ...

# %%
y_test=test[['PassengerId', 'Pclass', 'Age', 'Sex']]

# %%
y_test.dropna(how='any',inplace=True)
# Out:
# C:\Users\vipul\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.preprocessing import Imputer

# mark zero values as missing or NaN
#dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, numpy.NaN)
# fill missing values with mean column values
values = y_test.values
imputer = Imputer()
x_test = imputer.fit_transform(values)
# count the number of NaN values in each column

# %%
y_test
# Out:
#      PassengerId  Pclass   Age  Sex
# 0            892       3  34.5    1
# 1            893       3  47.0    0
# 2            894       2  62.0    1
# 3            895       3  27.0    1
# 4            896       3  22.0    0
# 5            897       3  14.0    1
# 6            898       3  30.0    0
# 7            899       2  26.0    1
# 8            900       3  18.0    0
# 9            901       3  21.0    1
# 11           903       1  46.0    1
# 12           904       1  23.0    0
# 13           905       2  63.0    1
# 14           906       1  47.0    0
# 15           907       2  24.0    0
# 16           908       2  35.0    1
# 17           909       3  21.0    1
# 18           910       3  27.0    0
# 19           911       3  45.0    0
# 20           912       1  55.0    1
# 21           913       3   9.0    1
# 23           915       1  21.0    1
# 24           916       1  48.0    0
# 25           917       3  50.0    1
# 26           918       1  22.0    0
# ...

# %%
x_test['Age'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-22e27f2cd3bf> in <module>()
# ----> 1 x_test['Age'].fillna(0, inplace=True)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
x_test

# %%
pr=clf.predict(x_test)

# %%
ans = pd.DataFrame({'PassengerId':x_test.PassengerId, 'Survived':(int)pr})

# %%
ans.to_csv('answer2.csv', index=False)

# %%
import csv

with open('answer2.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        print(row[0],row[1],sep=',')

# %%
x_test
